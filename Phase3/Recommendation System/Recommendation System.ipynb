# %% [markdown]
# # 1) Importing Necessary Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # 2) Loading The Dataset

# %%
cursor = sqlite3.connect(r'../../database/laptrack.db')

laptop_df = pd.read_sql_query("SELECT * FROM Laptop_Phase_2_2", cursor)

cursor.close()

laptop_df.head()
# Out:
#    Brand                       Laptop_Model_Name Laptop_Model_Number  \
# 0   Dell                    Latitude 3540 Laptop                None
# 1     HP                              17t-cn3004       17t-cn3004208
# 2   Dell  Dell Inspiron 15.6" Touchscreen Laptop                None
# 3  Apple                             MacBook Pro           Mvvm2ll/a
# 4     HP                                TPN-Q279            TPN-Q279
#
#   Processor_Brand Processor_Model Storage_Type         Operating_System  \
# 0           Intel           1355U          SSD  Windows 11 Professional
# 1           Intel   Intel Core i5          SSD           Windows 11 Pro
# 2           Intel           1355U          SSD           Windows 11 Pro
# 3           Intel         Core i9          SSD    Mac OS X 10.0 Cheetah
# 4             AMD         Ryzen 5          SSD          Windows 11 Home
#
#    Display_Resolution  Extracted_Rating  Battery_Life(Hours_Upto)  ...  Stock  \
# 0        1920x1080 MP               NaN                       NaN  ...      1
# 1     1600x900 Pixels               5.0                       NaN  ...      1
# 2    1920x1080 Pixels               NaN                       NaN  ...      1
# 3  2560 x 1600 Pixels               4.0                      11.0  ...      1
# 4  1920 x 1080 Pixels               3.8                       NaN  ...      1
#
#     Time_Of_Extraction                                                URL  \
# 0  2024-11-04 18:23:39  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 1  2024-11-04 18:23:42  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 2  2024-11-04 18:23:45  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 3  2024-11-04 18:23:54  https://www.amazon.com/2019-Apple-MacBook-16-i...
# 4  2024-11-04 18:23:57  https://www.amazon.com/HP-i7-1355U-i5-14400F-G...
#
#    Source Storage_Capacity(GB)  Display_Size(Inches)  RAM(GB)  No_Of_Reviews  \
# 0  Amazon                 4000                  15.6       64              0
# 1  Amazon                 4096                  17.3       64              0
# 2  Amazon                 4096                  15.6       32              0
# 3  Amazon                 2048                  16.0       16              0
# 4  Amazon                 2048                  15.6       16              0
#
#              Laptop_Dimensions Laptop_Weight(Pounds)
# 0   0.71 x 14.13 x 9.44 inches                  4.00
# 1  0.81 x 10.15 x 15.78 inches                  5.00
# 2   9.25 x 0.75 x 14.11 inches                  3.60
# 3  15.63 x 2.40 x 11.14 inches                  5.68
# 4  0.93 x 10.04 x 14.09 inches                  7.39
#
# [5 rows x 21 columns]

# %%
laptop_df.columns
# Out:
# Index(['Brand', 'Laptop_Model_Name', 'Laptop_Model_Number', 'Processor_Brand',
#        'Processor_Model', 'Storage_Type', 'Operating_System',
#        'Display_Resolution', 'Extracted_Rating', 'Battery_Life(Hours_Upto)',
#        'Price', 'Stock', 'Time_Of_Extraction', 'URL', 'Source',
#        'Storage_Capacity(GB)', 'Display_Size(Inches)', 'RAM(GB)',
#        'No_Of_Reviews', 'Laptop_Dimensions', 'Laptop_Weight(Pounds)'],
#       dtype='object')

# %%
laptop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4196 entries, 0 to 4195
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Brand                     4196 non-null   object
#  1   Laptop_Model_Name         4167 non-null   object
#  2   Laptop_Model_Number       3796 non-null   object
#  3   Processor_Brand           4166 non-null   object
#  4   Processor_Model           4196 non-null   object
#  5   Storage_Type              4196 non-null   object
#  6   Operating_System          4190 non-null   object
#  7   Display_Resolution        4169 non-null   object
#  8   Extracted_Rating          3490 non-null   float64
#  9   Battery_Life(Hours_Upto)  1145 non-null   float64
#  10  Price                     4196 non-null   float64
#  11  Stock                     4196 non-null   int64
#  12  Time_Of_Extraction        4196 non-null   object
#  13  URL                       4196 non-null   object
#  14  Source                    4196 non-null   object
#  15  Storage_Capacity(GB)      4196 non-null   int64
#  16  Display_Size(Inches)      3836 non-null   float64
#  17  RAM(GB)                   4196 non-null   int64
#  18  No_Of_Reviews             4196 non-null   int64
#  19  Laptop_Dimensions         3627 non-null   object
#  20  Laptop_Weight(Pounds)     3825 non-null   float64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 688.5+ KB

# %%
laptop_df.describe(include="all").T
# Out:
#                            count unique  \
# Brand                       4196     97
# Laptop_Model_Name           4167   2464
# Laptop_Model_Number         3796   2561
# Processor_Brand             4166      9
# Processor_Model             4196    299
# Storage_Type                4196      9
# Operating_System            4190     73
# Display_Resolution          4169    215
# Extracted_Rating          3490.0    NaN
# Battery_Life(Hours_Upto)  1145.0    NaN
# Price                     4196.0    NaN
# Stock                     4196.0    NaN
# Time_Of_Extraction          4196   4196
# URL                         4196   4196
# Source                      4196      3
# Storage_Capacity(GB)      4196.0    NaN
# Display_Size(Inches)      3836.0    NaN
# RAM(GB)                   4196.0    NaN
# No_Of_Reviews             4196.0    NaN
# Laptop_Dimensions           3627   1535
# Laptop_Weight(Pounds)     3825.0    NaN
#
#                                                                         top  \
# Brand                                                                    HP
# Laptop_Model_Name                                                        HP
# Laptop_Model_Number                                                 A325-42
# Processor_Brand                                                       Intel
# Processor_Model                                                     Core i5
# Storage_Type                                                            SSD
# Operating_System                                            Windows 11 Home
# Display_Resolution                                       1920 x 1080 Pixels
# Extracted_Rating                                                        NaN
# Battery_Life(Hours_Upto)                                                NaN
# Price                                                                   NaN
# Stock                                                                   NaN
# Time_Of_Extraction                                      2024-11-04 18:23:39
# URL                       https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# Source                                                               Amazon
# Storage_Capacity(GB)                                                    NaN
# Display_Size(Inches)                                                    NaN
# RAM(GB)                                                                 NaN
# No_Of_Reviews                                                           NaN
# Laptop_Dimensions                               0.78 x 10.15 x 15.78 inches
# Laptop_Weight(Pounds)                                                   NaN
#
#                           freq         mean          std    min     25%  \
# Brand                      994          NaN          NaN    NaN     NaN
# Laptop_Model_Name           61          NaN          NaN    NaN     NaN
# Laptop_Model_Number         43          NaN          NaN    NaN     NaN
# Processor_Brand           3309          NaN          NaN    NaN     NaN
# Processor_Model            508          NaN          NaN    NaN     NaN
# Storage_Type              4047          NaN          NaN    NaN     NaN
# Operating_System          1649          NaN          NaN    NaN     NaN
# Display_Resolution         608          NaN          NaN    NaN     NaN
# Extracted_Rating           NaN     4.236304     0.532802    1.0     4.0
# Battery_Life(Hours_Upto)   NaN    12.033013    25.875707   0.01     8.0
# Price                      NaN   842.118239   665.883846  44.99  407.33
# Stock                      NaN          1.0          0.0    1.0     1.0
# Time_Of_Extraction           1          NaN          NaN    NaN     NaN
# URL                          1          NaN          NaN    NaN     NaN
# Source                    2091          NaN          NaN    NaN     NaN
# Storage_Capacity(GB)       NaN  1074.086511  1247.719175    1.0   512.0
# Display_Size(Inches)       NaN    14.991715     1.339508    4.0    14.0
# RAM(GB)                    NaN    19.806959    22.564708    2.0     8.0
# No_Of_Reviews              NaN    34.693994   470.825304    0.0     0.0
# Laptop_Dimensions          137          NaN          NaN    NaN     NaN
# Laptop_Weight(Pounds)      NaN     4.770316    36.766237  0.212     3.2
#
#                               50%      75%      max
# Brand                         NaN      NaN      NaN
# Laptop_Model_Name             NaN      NaN      NaN
# Laptop_Model_Number           NaN      NaN      NaN
# Processor_Brand               NaN      NaN      NaN
# Processor_Model               NaN      NaN      NaN
# Storage_Type                  NaN      NaN      NaN
# Operating_System              NaN      NaN      NaN
# Display_Resolution            NaN      NaN      NaN
# Extracted_Rating              4.3      4.5      5.0
# Battery_Life(Hours_Upto)     10.0     13.0    850.0
# Price                     642.495  1089.99  6099.99
# Stock                         1.0      1.0      1.0
# Time_Of_Extraction            NaN      NaN      NaN
# URL                           NaN      NaN      NaN
# Source                        NaN      NaN      NaN
# Storage_Capacity(GB)        512.0   2048.0  16384.0
# Display_Size(Inches)         15.6     16.0     18.0
# RAM(GB)                      16.0     24.0    512.0
# No_Of_Reviews                 0.0      0.0  24919.0
# Laptop_Dimensions             NaN      NaN      NaN
# Laptop_Weight(Pounds)        3.72      4.6   2268.0

# %% [markdown]
# # 3) Building Content Based Recommendation System

# %%
# Defining the Recommender Class
class LaptopRecommender:
    def __init__(self, df):
        self.df = df.copy()
        self.similarity_matrix = None
        self.processed_features = None
        
    def preprocess_data(self):
        """Preprocess the data for recommendation system"""
        # Extract numerical value from display resolution
        self.df['resolution_pixels'] = self.df['Display_Resolution'].str.extract('(\d+)').astype(float)
        
        # Convert processor brands and models to categorical
        self.df['Processor_Brand'] = pd.Categorical(self.df['Processor_Brand']).codes
        self.df['Processor_Model'] = pd.Categorical(self.df['Processor_Model']).codes
        self.df['Brand'] = pd.Categorical(self.df['Brand']).codes
        self.df['Storage_Type'] = pd.Categorical(self.df['Storage_Type']).codes
        
        # Select features for similarity calculation
        features = [
            'Brand', 'Processor_Brand', 'Processor_Model', 'Storage_Type',
            'Storage_Capacity(GB)', 'RAM(GB)', 'Price', 'Display_Size(Inches)',
            'resolution_pixels', 'Laptop_Weight(Pounds)', 'Extracted_Rating'
        ]
        
        # Handle missing values
        feature_df = self.df[features].copy()
        feature_df = feature_df.fillna(feature_df.mean())
        
        # Scale features
        scaler = MinMaxScaler()
        self.processed_features = pd.DataFrame(
            scaler.fit_transform(feature_df),
            columns=features
        )
        
        # Calculate similarity matrix
        self.similarity_matrix = cosine_similarity(self.processed_features)
        
    def get_recommendations(self, laptop_index, n_recommendations=5):
        """Get n similar laptop recommendations for a given laptop index"""
        if self.similarity_matrix is None:
            self.preprocess_data()
            
        # Get similarity scores
        sim_scores = list(enumerate(self.similarity_matrix[laptop_index]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        
        # Get top N most similar laptops (excluding itself)
        sim_scores = sim_scores[1:n_recommendations+1]
        laptop_indices = [i[0] for i in sim_scores]
        
        # Get relevant information for recommended laptops
        recommendations = self.df.iloc[laptop_indices][
            ['Brand', 'Laptop_Model_Name', 'Processor_Model', 
             'RAM(GB)', 'Storage_Capacity(GB)', 'Price', 'Extracted_Rating']
        ].copy()
        
        # Add similarity scores
        recommendations['Similarity_Score'] = [i[1] for i in sim_scores]
        
        return recommendations
    
    def get_recommendations_by_features(self, features_dict, n_recommendations=5):
        """Get recommendations based on user-specified features"""
        if self.similarity_matrix is None:
            self.preprocess_data()
            
        # Create a feature vector for the specified features
        query_features = self.processed_features.mean().to_dict()  # Default values
        
        # Map categorical features
        if 'Brand' in features_dict:
            brand_mapping = dict(enumerate(self.df['Brand'].unique()))
            brand_mapping = {v: k for k, v in brand_mapping.items()}
            features_dict['Brand'] = brand_mapping.get(features_dict['Brand'], 0)
            
        # Update with user-specified features
        for feature, value in features_dict.items():
            if feature in query_features:
                query_features[feature] = value
                
        # Convert to DataFrame
        query_df = pd.DataFrame([query_features])
        
        # Calculate similarity with all laptops
        similarities = cosine_similarity(query_df, self.processed_features)[0]
        
        # Get top N recommendations
        top_indices = similarities.argsort()[-n_recommendations:][::-1]
        
        # Get relevant information for recommended laptops
        recommendations = self.df.iloc[top_indices][
            ['Brand', 'Laptop_Model_Name', 'Processor_Model', 
             'RAM(GB)', 'Storage_Capacity(GB)', 'Price', 'Extracted_Rating']
        ].copy()
        
        # Add similarity scores
        recommendations['Similarity_Score'] = similarities[top_indices]
        
        return recommendations

# %%
def format_recommendations(recommendations):
    """Format recommendations for display"""
    recommendations['Price'] = recommendations['Price'].map('${:,.2f}'.format)
    recommendations['Similarity_Score'] = recommendations['Similarity_Score'].map('{:.2%}'.format)
    return recommendations.reset_index(drop=True)

# %%
# Initialize the recommender
recommender = LaptopRecommender(laptop_df)

# Get recommendations similar to a specific laptop (e.g., index 0)
similar_laptops = recommender.get_recommendations(0)
format_recommendations(similar_laptops)
# Out:
#    Brand     Laptop_Model_Name  Processor_Model  RAM(GB)  \
# 0     23  Latitude 3540 Laptop               14       64
# 1     23  Latitude 3540 Laptop               14       64
# 2     23  Latitude 3540 Laptop               14       64
# 3     23  Latitude 3540 Laptop               14       64
# 4     23  Latitude 3540 Laptop               14       64
#
#    Storage_Capacity(GB)      Price  Extracted_Rating Similarity_Score
# 0                  4000  $1,772.95               NaN          100.00%
# 1                  4000  $1,772.95               NaN          100.00%
# 2                  4000  $1,772.95               NaN          100.00%
# 3                  4000  $1,772.95               NaN          100.00%
# 4                  4000  $1,772.95               NaN          100.00%

# %%
# Get recommendations based on specific features
features = {
    'Brand': 'Dell',
    'Price': 1000,
    'RAM(GB)': 16,
    'Storage_Capacity(GB)': 512
}
feature_based_recommendations = recommender.get_recommendations_by_features(features)
format_recommendations(feature_based_recommendations)
# Out:
#    Brand          Laptop_Model_Name  Processor_Model  RAM(GB)  \
# 0     50               ThinkPad P15              259      128
# 1     38             Envy 16t-h1000              126        4
# 2     52   Titan 18 HX A14VIG-036US              214      128
# 3     11                MacBook Pro              250      128
# 4     50  Lenovo ThinkPad P16 Gen 2              214      128
#
#    Storage_Capacity(GB)      Price  Extracted_Rating Similarity_Score
# 0                 16384  $6,099.99               3.1           61.70%
# 1                 16384  $3,429.99               NaN           50.64%
# 2                  8192  $5,496.00               4.5           49.10%
# 3                  4096  $5,259.00               NaN           46.99%
# 4                  8192  $5,000.00               5.0           46.67%

# %% [markdown]
# This recommendation system has several key features:
#
# - Content-based filtering using multiple relevant laptop features
# - Handles both categorical and numerical data
# - Provides recommendations in two ways:
# - Similar laptops to an existing laptop
# - Recommendations based on user-specified features
# - Includes proper preprocessing and scaling of features
# - Returns similarity scores with recommendations
